# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/startup_funding.csv')

# %%
df.drop(columns=['Remarks'], inplace=True)

# %%
df.head()
# Out:
#    Sr No Date dd/mm/yyyy                  Startup Name    Industry Vertical  \
# 0      1      09/01/2020                        BYJU’S               E-Tech
# 1      2      13/01/2020                        Shuttl       Transportation
# 2      3      09/01/2020                     Mamaearth           E-commerce
# 3      4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 4      5      02/01/2020                        Fashor  Fashion and Apparel
#
#                              SubVertical City  Location  \
# 0                             E-learning      Bengaluru
# 1              App based shuttle service        Gurgaon
# 2  Retailer of baby and toddler products      Bengaluru
# 3                      Online Investment      New Delhi
# 4            Embroiled Clothes For Women         Mumbai
#
#               Investors Name       InvestmentnType Amount in USD
# 0    Tiger Global Management  Private Equity Round  20,00,00,000
# 1  Susquehanna Growth Equity              Series C     80,48,394
# 2      Sequoia Capital India              Series B   1,83,58,860
# 3             Vinod Khatumal          Pre-series A     30,00,000
# 4    Sprout Venture Partners            Seed Round     18,00,000

# %%
df.set_index('Sr No', inplace=True)

# %%
df.rename(columns={
    'Date dd/mm/yyyy':'date',
    'Startup Name':'startup',
    'Industry Vertical':'vertical',
    'SubVertical': 'subvertical',
    'City  Location': 'city',
    'Investors Name':'investors',
    'InvestmentnType':'round',
    'Amount in USD':'amount'
}, inplace=True)

# %%
df.head()
# Out:
#              date                       startup             vertical  \
# Sr No
# 1      09/01/2020                        BYJU’S               E-Tech
# 2      13/01/2020                        Shuttl       Transportation
# 3      09/01/2020                     Mamaearth           E-commerce
# 4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 5      02/01/2020                        Fashor  Fashion and Apparel
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# 2                  App based shuttle service    Gurgaon
# 3      Retailer of baby and toddler products  Bengaluru
# 4                          Online Investment  New Delhi
# 5                Embroiled Clothes For Women     Mumbai
#
#                        investors                 round        amount
# Sr No
# 1        Tiger Global Management  Private Equity Round  20,00,00,000
# 2      Susquehanna Growth Equity              Series C     80,48,394
# 3          Sequoia Capital India              Series B   1,83,58,860
# 4                 Vinod Khatumal          Pre-series A     30,00,000
# 5        Sprout Venture Partners            Seed Round     18,00,000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3044 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3044 non-null   object
#  1   startup      3044 non-null   object
#  2   vertical     2873 non-null   object
#  3   subvertical  2108 non-null   object
#  4   city         2864 non-null   object
#  5   investors    3020 non-null   object
#  6   round        3040 non-null   object
#  7   amount       2084 non-null   object
# dtypes: object(8)
# memory usage: 214.0+ KB

# %%
df['amount']=df['amount'].fillna('0')

# %%
df['amount']=df['amount'].str.replace(',','')

# %%
df['amount']=df['amount'].str.replace('undisclosed','0')
df['amount']=df['amount'].str.replace('unknown','0')
df['amount']=df['amount'].str.replace('Undisclosed','0')

# %%
df=df[df['amount'].str.isdigit()]

# %%
df['amount']=df['amount'].astype('float')

# %%
df.head()
# Out:
#              date                       startup             vertical  \
# Sr No
# 1      09/01/2020                        BYJU’S               E-Tech
# 2      13/01/2020                        Shuttl       Transportation
# 3      09/01/2020                     Mamaearth           E-commerce
# 4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 5      02/01/2020                        Fashor  Fashion and Apparel
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# 2                  App based shuttle service    Gurgaon
# 3      Retailer of baby and toddler products  Bengaluru
# 4                          Online Investment  New Delhi
# 5                Embroiled Clothes For Women     Mumbai
#
#                        investors                 round       amount
# Sr No
# 1        Tiger Global Management  Private Equity Round  200000000.0
# 2      Susquehanna Growth Equity              Series C    8048394.0
# 3          Sequoia Capital India              Series B   18358860.0
# 4                 Vinod Khatumal          Pre-series A    3000000.0
# 5        Sprout Venture Partners            Seed Round    1800000.0

# %%
def to_inr(dollar):
    inr = dollar * 82.5
    return inr/10000000

# %%
df['amount']=df['amount'].apply(to_inr)

# %%
df['date']=df['date'].str.replace('05/072018','05/07/2018')

# %%
df['date']=df['date'].str.replace('01/07/015', '01/07/2015')

# %%
df['date']=df['date'].str.replace('.', '/')

# %%
df['date']=df['date'].str.replace('//', '/')

# %%
df['date']=pd.to_datetime(df['date'], dayfirst=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3029 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3029 non-null   datetime64[ns]
#  1   startup      3029 non-null   object
#  2   vertical     2858 non-null   object
#  3   subvertical  2104 non-null   object
#  4   city         2849 non-null   object
#  5   investors    3005 non-null   object
#  6   round        3027 non-null   object
#  7   amount       3029 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 213.0+ KB

# %%
df.sample(10)
# Out:
#             date       startup                              vertical  \
# Sr No
# 1314  2016-10-19        Fisdom                     Consumer Internet
# 1     2020-01-09        BYJU’S                                E-Tech
# 895   2017-04-17     Snackible                      Food & Beverages
# 1330  2016-10-26  The Kettlery                             eCommerce
# 2418  2015-09-15      MoEngage  Mobile Marketing Automation Platform
# 1996  2016-02-25    OfBusiness                             eCommerce
# 926   2017-03-01        Belong                     Consumer Internet
# 2777  2015-05-12      Plancess             Online Education Platform
# 2701  2015-06-10       Guiddoo               Travel Guide Mobile App
# 1209  2016-11-10      Tone Tag                            Technology
#
#                                      subvertical       city  \
# Sr No
# 1314   Personal Wealth Management Platform & App  Bangalore
# 1                                     E-learning  Bengaluru
# 895                  Healthy Snacks manufacturer     Mumbai
# 1330                          Online Tea Etailer  Ahmedabad
# 2418                                         NaN  Bangalore
# 1996                    B2B commerce Marketplace    Gurgaon
# 926                            Online Jon Portal  Bangalore
# 2777                                         NaN     Mumbai
# 2701                                         NaN     Mumbai
# 1209                Contactless Payment Solution  Bangalore
#
#                                                investors  \
# Sr No
# 1314   Saama Capital, Raghunandan G, Aprameya Radhakr...
# 1                                Tiger Global Management
# 895    Nibhrant Shah, Anandbir Singh, Anirudh Sheth, ...
# 1330   hooting Starts Sports LLP, Franchise India Brands
# 2418          Helion Venture Partners, Exfinity Ventures
# 1996                               Matrix Partners India
# 926                                Sequoia Capital India
# 2777         Rajendra Gogri,\\xc2\\xa0 Chandrakant Gogri
# 2701                 Pawan Borle, SVP Fly Dubai & Others
# 1209   Arun Seth, T.V. Mohandas Pai, Anand Chandrasek...
#
#                       round      amount
# Sr No
# 1314         Private Equity     9.07500
# 1      Private Equity Round  1650.00000
# 895            Seed Funding     1.44375
# 1330         Private Equity     8.25000
# 2418         Private Equity    35.06250
# 1996         Private Equity    41.25000
# 926          Private Equity    82.50000
# 2777           Seed Funding    16.50000
# 2701           Seed Funding     0.00000
# 1209         Private Equity     0.00000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3029 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3029 non-null   datetime64[ns]
#  1   startup      3029 non-null   object
#  2   vertical     2858 non-null   object
#  3   subvertical  2104 non-null   object
#  4   city         2849 non-null   object
#  5   investors    3005 non-null   object
#  6   round        3027 non-null   object
#  7   amount       3029 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 213.0+ KB

# %%
df = df.dropna(subset=['date', 'startup', 'vertical', 'city', 'investors', 'round', 'amount'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2823 entries, 1 to 2873
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         2823 non-null   datetime64[ns]
#  1   startup      2823 non-null   object
#  2   vertical     2823 non-null   object
#  3   subvertical  2078 non-null   object
#  4   city         2823 non-null   object
#  5   investors    2823 non-null   object
#  6   round        2823 non-null   object
#  7   amount       2823 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 198.5+ KB
